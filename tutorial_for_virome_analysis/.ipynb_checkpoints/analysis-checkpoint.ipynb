# %%
source("../NeTaGFT.R")

# %%
m <- 100

A <- as.matrix(read.table("data/A_k200.txt"))
X <- as.matrix(read.table("data/X_k200.txt",header = TRUE))
for(i in 1:dim(X)[2]){
  X[,i] <- X[,i] / sqrt(sum(X[,i]**2))
}

#construct graph Laplacian
L <- sym_normalized_graph_laplacian(A)

#perform GFT
tmp <- graph_fourier_transform(L,X,m)
U <- tmp$U
eigenvalues <- tmp$eigenvalues
hF <- tmp$hF
tF <- tmp$tF

# %%
#plot GF coefficients
barplot_gfdomain(hF,tF,2)
barplot_gfdomain(hF,tF,3)
barplot_gfdomain(hF,tF,4)
# Out:
# Plot with title “2”
# Plot with title “3”
# Plot with title “4”

# %%
#plot GLR
plot_aGLR(X, U, 100)
# Out:
# plot without title
