# %%
source("NeTaGFT.R")

# %%
m <- 100

A <- as.matrix(read.table("dataset_HA/A.txt"))
X <- as.matrix(read.table("dataset_HA/X.txt",header = TRUE))
for(i in 1:dim(X)[2]){
  X[,i] <- X[,i] / sqrt(sum(X[,i]**2))
}

#construct graph Laplacian
L <- sym_normalized_graph_laplacian(A)

#perform GFT
tmp <- graph_fourier_transform(L,X,m)
U <- tmp$U
eigenvalues <- tmp$eigenvalues
hF <- tmp$hF
tF <- tmp$tF

# %%
#plot eigenvalues to confirm the value of m is sufficient
plot(eigenvalues)
# Out:
# plot without title

# %%
#plot GF coefficients
barplot_gfdomain(hF,tF,2)
barplot_gfdomain(hF,tF,3)
barplot_gfdomain(hF,tF,4)
barplot_gfdomain(hF,tF,5)
barplot_gfdomain(hF,tF,6)
barplot_gfdomain(hF,tF,7)
# Out:
# Plot with title “2”
# Plot with title “3”
# Plot with title “4”
# Plot with title “5”
# Plot with title “6”
# Plot with title “7”

# %%
target_trait_idx <- c(1:3,14:16)
plot_hF_with_shuffleddata(hF[,target_trait_idx], X[,target_trait_idx], 7)
plot_tF_with_shuffleddata(tF[,target_trait_idx], X[,target_trait_idx], 7)
# Out:
# Plot with title “hF_7”
# Plot with title “tF_7”

# %%
#plot aGLR
plot_aGLR(X, U, 100)
# Out:
# plot without title
